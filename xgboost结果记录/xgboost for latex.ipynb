# %%
Accuracies = [0.83293, 0.87523, 0.88712, 0.8898900000000001, 0.8908799999999999]
for i in range(5):
    Accuracies[i] *= 100
for i in Accuracies:
    print(round(i,2))
# Out:
# 83.29
# 87.52
# 88.71
# 88.99
# 89.09

# %%
# print(round(870.4754884243011,1))
# print(round(1668.0489115715027,1))
# print(round(2271.471433162689,1))
# print(round(2528.4288380146027,1))
# print(round(2730.132282972336,1))
times = [870.5,1668.0, 2271.5,2528.4,2730.1]
print (times)
# Out:
# [870.5, 1668.0, 2271.5, 2528.4, 2730.1]

# %%
Time_For_Each_Tree = [0.957, 2.057, 3.215,5.713, 8.651]
# for i in Time_For_Each_Tree:
#     print(round(i,2))

# %%
precision = [0.83238745, 0.99404861, 0.7958014 , 0.89054297 ,0.80598951, 0.98481196,
 0.7233224 , 0.94283464, 0.96934791 ,0.96456412]
recall = [0.8601, 0.9684 ,0.8242, 0.9062, 0.8276, 0.9658, 0.6542, 0.9681, 0.9736, 0.9606]
f1 = [0.84600229, 0.981055  , 0.80973211, 0.8982955,  0.81663519, 0.9752106,
 0.68698484, 0.95529778, 0.97146503 ,0.96257417]

# %%
for i in range(10):
    print("{%d} & %.3f  &  %.3f  &  %.3f \n\\\ \n\hline"% (i,precision[i],recall[i],f1[i]))
# Out:
# {0} & 0.832  &  0.860  &  0.846
# \\
# \hline
# {1} & 0.994  &  0.968  &  0.981
# \\
# \hline
# {2} & 0.796  &  0.824  &  0.810
# \\
# \hline
# {3} & 0.891  &  0.906  &  0.898
# \\
# \hline
# {4} & 0.806  &  0.828  &  0.817
# \\
# \hline
# {5} & 0.985  &  0.966  &  0.975
# \\
# \hline
# {6} & 0.723  &  0.654  &  0.687
# \\
# \hline
# {7} & 0.943  &  0.968  &  0.955
# \\
# \hline
# {8} & 0.969  &  0.974  &  0.971
# \\
# \hline
# {9} & 0.965  &  0.961  &  0.963
# \\
# \hline

# %%
import matplotlib.pyplot as plt
depths = [1,3,5,7,9]
fig=plt.figure()

plt.plot(depths,Accuracies,marker='o')
plt.xlabel("max_depth")
plt.ylabel("accuracy")
plt.title("XGBoost accuracy")
plt.ylim(ymin=82)
plt.show()

# %%
import matplotlib.pyplot as plt
depths = [1,3,5,7,9]

plt.plot(depths,times ,marker='o')
plt.xlabel("max_depth")
plt.ylabel("time for each iteration (s)")
plt.title("XGBoost time for each iteration")
plt.ylim(ymin=870)
plt.show()
