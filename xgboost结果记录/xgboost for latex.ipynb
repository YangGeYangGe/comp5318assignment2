# %%
Accuracies = [0.864, 0.8896, 0.8909, 0.8896, 0.8881]
for i in range(5):
    Accuracies[i] *= 100
for i in Accuracies:
    print(i)
# Out:
# 86.4
# 88.96
# 89.09
# 88.96
# 88.81

# %%
print(100+1+5)
print(88+1+5)
print(65+1+5)
print(53+1+5)
print(64+1+5)
# Out:
# 106
# 94
# 71
# 59
# 70

# %%
print(round(101.3987603187561,1))
print(round(193.35744953155518,1))
print(round(228.265531539917,1))
print(round(337.086443901062,1))
print(round(605.5902621746063,1))
# Out:
# 101.4
# 193.4
# 228.3
# 337.1
# 605.6

# %%
Time_For_Each_Tree = [0.957, 2.057, 3.215,5.713, 8.651]
# for i in Time_For_Each_Tree:
#     print(round(i,2))

# %%
precision = [0.832, 0.995, 0.792, 0.896, 0.817, 0.98 , 0.713, 0.944, 0.973,
       0.962]
recall = [0.845, 0.983, 0.809, 0.902, 0.821, 0.972, 0.682, 0.954, 0.974,
       0.961]
f1 = [0.859, 0.972, 0.827, 0.907, 0.826, 0.965, 0.653, 0.964, 0.975,
       0.961]

# %%
for i in range(10):
    print("{%d} & %.3f  &  %.3f  &  %.3f \n\\\ \n\hline"% (i,precision[i],recall[i],f1[i]))

# %%
import matplotlib.pyplot as plt
depths = [2,4,6,10,15]
fig=plt.figure()

plt.plot(depths,Accuracies,marker='o')
plt.xlabel("max_depth")
plt.ylabel("accuracy")
plt.title("XGBoost accuracy")
plt.ylim(ymin=86)
plt.show()

# %%
import matplotlib.pyplot as plt
depths = [2,4,6,10,15]

plt.plot(depths,Time_For_Each_Tree,marker='o')
plt.xlabel("max_depth")
plt.ylabel("time for each iteration (s)")
plt.title("XGBoost time for each iteration")
plt.ylim(ymin=0.85)
plt.show()
